# %%
"""
this class

"""

class StudentInfo:


    def sum ():
        pass

    def sub():
        pass

# %%
class StudentInfo:
    student_name ="mariam"
    student_age = 4
    Gpa = 3.9
    gender ="female"

    def student_info(self):
        # self must be been because this is  refer to the object 

        return f"welcome into depi program"

# %%
s1 = StudentInfo()
s1.student_name ="salma"
s1.student_name 
s1.student_info()
# Out:
# 'welcome into depi program'

# %%
class StudentInfo:
    student_name ="mariam"
    student_age = 4
    Gpa = 3.9
    gender ="female"

    def student_info(self):
        print(self)

# %%
s1=StudentInfo()
print(s1)
print(s1.student_info())
# Out:
# ...
# None

# %%
class StudentInfo:


    def __init__(self, name="test", age=19):
        self.name = name
        self.age = age

    
    #double under score
    def student_info(self):
        return self.name , self.age
       # return f"{self.name} , {self.age}"

# %%
s1= StudentInfo("mariam",19)
print(s1.student_info())
# Out:
# ('mariam', 19)

# %%
#Abstruction


from abc import ABC , abstractmethod

class Animal(ABC):
    @abstractmethod
    def move(self):
       pass

class Bird(Animal):
    def move(self):
        print("move from bird")



class Cat(Animal):
    def move(self):
       print("move from Cat")

# %%
a= Bird()
a.move()
# Out:
# move from bird

# %%
a= Animal()
#Can't instantiate abstract class Animal without an implementation for abstract method 'move'
a.move()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 a= Animal()
#       2 a.move()
#
# TypeError: Can't instantiate abstract class Animal without an implementation for abstract method 'move'

# %%
a= Bird()
a.move()
# Out:
# move from bird

# %%
#Abstruction


from abc import ABC , abstractmethod

class Animal(ABC):
    @abstractmethod
    def move(self):
       pass

class Bird(Animal):
    
        pass



class Cat(Animal):
    def move(self):
       print("move from Cat")

# %%
a= Bird()
a.move()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 a= Bird()
#       2 a.move()
#
# TypeError: Can't instantiate abstract class Bird without an implementation for abstract method 'move'

# %%
class Car:
# private Attribute
_  engine_capacity - "2000cc"

   s private method
    private metnod
def _start_engine(self):
print("Engine started!")

c1 - Car()

print(c1 ._ engine_capacity)

c1 ._ start_engine()

AttributeError
Cell In[3], line 11
print("Engine started!")
9 c1 =
--- > 11 print(c1 ._ engine_capacity)
14 c1 ._ start_engine()

# %%
class A():
   def do_this(self):
     print("I am in A")

class B(A):
   pass

class C():
    def do_this(self):
       print("I am in C")

class D(C,B):
   pass

x = D()
x.do_this()
# Out:
# I am in C

# %%
class A():
   def do_this(self):
     print("I am in A")

class B(A):
   pass

class C():
    def do_this(self):
       print("I am in C")

class D(B,C):
   pass

x = D()
x.do_this()
# Out:
# I am in A
