# %%
def user_info(name , age):
    """
    this function take name and age from user and return again
    :param_1 : take the name of user from input user interface 
    type param_1 : str
    :param_2 : take the age of user from input user interface 
    type param_2 : int

    return : this function will print the name and the age
    rtype: str , int

    """
    return f"my name is {name} , my age is {age}"

# %%
user_info(age =19 , name ="mariam")
# Out:
# 'my name is mariam , my age is 19'

# %%
from user_info import user_info
user_info
# Out:
# <function user_info.user_info(name, age)>

# %%
def user_info(**name):
    print(name)
    print(type(name))

# %%
print(user_info)
print(type(user_info))
# Out:
# <function user_info at 0x0000021473B9F920>
# <class 'function'>

# %%
result=lambda x:x+10
print(result)
print(type(result))
print(result(10))
# Out:
# <function <lambda> at 0x0000021473C06E80>
# <class 'function'>
# 20

# %%
function_name = lambda x,y:x+y
print(function_name(5,10))
# Out:
# 15

# %%
# quiz

# %%
def fun (x):
    print("inside:",x)
fun(20)
print("outside:",x)
# Out:
# inside: 20
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       2     print("inside:",x)
#       3 fun(20)
# ----> 4 print("outside:",x)
#
# NameError: name 'x' is not defined

# %%
x="global"
def outer_fun ():
    x="outer_local"
    def inner_fun():
        global x
        x="changed"
        print("inside inner func",x)
    inner_fun()
    print("inside outer fun:",x) 
outer_fun()
print("outer any func:",x)
# Out:
# inside inner func changed
# inside outer fun: outer_local
# outer any func: changed

# %%
5 /0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 5 /0
#
# ZeroDivisionError: division by zero

# %%
x=int(input())
y=int(input())
try:
    x/y
except:
    print("not allow to divide by zero")
# Out:
# not allow to divide by zero

# %%
x=int(input())
y=int(input())
try:
    5/0
except Exception as e:
    print(" ",e)
# Out:
#   division by zero

# %%
def sum (num_1 : int ,num_2 : int):
    return num_1 + num_2

# %%
try:
    x= 10
    y= int(input())
    x/y
except:
    print("Division by zero")
finally:
    print("done")   
    # finally done anyway if y=0 or no
# Out:
# done

# %%
from random import randint,random
randint(0,10)

# choooose a random value between this
# Out:
# 0

# %%
from random import randint,random
random()
# Out:
# 0.24961870799713404

# %%
import os

# %%
base_dire =r"C:\Users\zbook g6\Desktop\DEBI-ONL4_AIS2_S2\DEBI-ONL4_AIS2_S2\src\machine_learning\python\session_5\file_handle"

# %%
file_names = os.listdir(base_dire)
type(file_names)
file_names
# Out:
# ['test.txt']

# %%
base_dire= "./tem_dir"
file_name ="txt_1.txt"
file_path = os.path.join(base_dire,file_name)
file_path
# Out:
# './tem_dir\\txt_1.txt'

# %%
import os 
dir =r"C:\Users\zbook g6\Desktop\DEBI-ONL4_AIS2_S2\DEBI-ONL4_AIS2_S2\src\machine_learning\python\session_5\__pycache__test"
if not os.path.exists(dir):
    os.makedirs(dir)
else:
    print("the path is exist",dir)

# %%
import os 
dir =r"C:\Users\zbook g6\Desktop\DEBI-ONL4_AIS2_S2\DEBI-ONL4_AIS2_S2\src\machine_learning\python\session_5\__pycache__test"
if not os.path.exists(dir):
    os.makedirs(dir)
for i in range(20):
    inner_path = os.path.join(dir,"dir_"+str(i))
    if not os.path.exists(inner_path):
        os.makedirs(inner_path)
