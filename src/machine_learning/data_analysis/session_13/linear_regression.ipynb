# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x= np.array([1,2,3,4])
y= np.array([2,2.8,3.6,4.5])

# %%
w=0
b=0
alpha=0.1
num_iteration=20

# %%
sse_value=[]
for i in range (num_iteration):
    y_hat= w * x + b
    D_w = 2/4 * np.sum((y_hat - y)*x)
    D_b= 2/4 * np.sum(y_hat - y)
    w = w - alpha * D_w
    # w -= alpha * D_w
    b = b - alpha * D_b
    # b -= alpha * D_b
    sse = (np.sum((y_hat - y)**2))
    sse_value.append(sse)

    if(i+1) % 20 == 0 :
        print(f"iteration {i+1},sse{sse}")
# Out:
# iteration 20,sse0.0004417275854453806

# %%
print(f"Optimized param : slop ={w},bais ={b}")
# Out:
# Optimized param : slop =1.0588363341924316,bais =0.3831394046004588

# %%
plt.Figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(range(num_iteration),sse_value, label='sse')
plt.xlabel("Iteration")
plt.ylabel("SSE")
plt.title("SSE over Iteration")
plt.legend()
plt.subplot(1,2,2)
plt.scatter(x,y,color ="blue",label="Data points")
plt.plot(x,w*x+b,color ="red",label="Regression line ")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Linear Hegression fil")
plt.show()

# %%
y= w * x + b
y
# Out:
# array([1.44197574, 2.50081207, 3.55964841, 4.61848474])

# %%
class LinearRegression_M:
    def __init__(self,alpha):
        pass
    def fit_M(self,x):
        pass
    def

# %%
l= LinearRegression_M()
l.fit_M()

# %%
x_new = int(input("please Enter new value "))
y = w * x_new + b
y
# Out:
# np.float64(6.736157409755049)

# %%
from sklearn.linear_model import LinearRegression 
L1= LinearRegression_M()
L1.fit_M()
