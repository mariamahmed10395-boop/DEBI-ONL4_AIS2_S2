# %%
import pandas as pd

# %%
s= pd.Series([1,2,3,4])
type(s)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s1=pd.Series([1,2,3,4],index=['A','B','C','D'])
s1
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %%
data=[[1,444,'abc'],
      [2,555,'def'],
      [3,666,'ghi'],
      [4,777,'xyz']]
df= pd.DataFrame(data,columns=['ID','std_id','Dept'])
df
# Out:
#    ID  std_id Dept
# 0   1     444  abc
# 1   2     555  def
# 2   3     666  ghi
# 3   4     777  xyz

# %%
data_2={ 'ID':[1,2,3,4],
        'std_id':[444,555,666,777],
        'Dept':['abc','def','ghi','xyz']

}
df=pd.DataFrame(data_2)
df
# Out:
#    ID  std_id Dept
# 0   1     444  abc
# 1   2     555  def
# 2   3     666  ghi
# 3   4     777  xyz

# %% [markdown]
#  dataframe can read from all of all exel file, datafram

# %%
df=pd.DataFrame(data_2)
display(df)
# Out:
#    ID std_id Dept
# 0   1    444  abc
# 1   2    555  def
# 2   3    666  ghi
# 3   4    777  xyz

# %%
df.columns
# Out:
# Index(['ID', 'std_id', 'Dept'], dtype='object')

# %%
index =['row1','row2','row3','row4']
df.index =index
display(df)
# Out:
#       ID  std_id  Dept
# row1   1     444   NaN
# row2   2     555   NaN
# row3   3     666   NaN
# row4   4     777   NaN

# %% [markdown]
# poriroty of them
#
#  object,string,float,integer,boolen
#  if you see one of them it dominate of all the whole

# %%
class student:
    def __init__(self,)

# %%
p1=
p1.getinfo

# %%
df.dtypes
# Out:
# ID         int64
# std_id     int64
# Dept      object
# dtype: object

# %%
df['Dept'].dtype
# Out:
# dtype('O')

# %%
df['Dept']=df['Dept'].astype('category')

# %%
df.dtypes
# Out:
# ID           int64
# std_id       int64
# Dept      category
# dtype: object

# %%
df.head()
#first 5 elements
# Out:
#    ID  std_id Dept
# 0   1     444  abc
# 1   2     555  def
# 2   3     666  ghi
# 3   4     777  xyz

# %%
df.tail()
#last 5 elements
# Out:
#    ID  std_id Dept
# 0   1     444  abc
# 1   2     555  def
# 2   3     666  ghi
# 3   4     777  xyz

# %%
df.tail(2)
#last 2 elements
# Out:
#    ID  std_id Dept
# 2   3     666  ghi
# 3   4     777  xyz

# %%
df.describe()
# Out:
#              ID      std_id
# count  4.000000    4.000000
# mean   2.500000  610.500000
# std    1.290994  143.300384
# min    1.000000  444.000000
# 25%    1.750000  527.250000
# 50%    2.500000  610.500000
# 75%    3.250000  693.750000
# max    4.000000  777.000000

# %%
df.describe(include='category')
# Out:
#        Dept
# count     4
# unique    4
# top     abc
# freq      1

# %%
df.columns
# Out:
# Index(['ID', 'std_id', 'Dept'], dtype='object')

# %%
df['std_id'].unique().sum()
# Out:
# np.int64(2442)

# %%
df['std_id'].max()
# Out:
# np.int64(777)

# %%
df['std_id'].min()
# Out:
# np.int64(444)

# %%
df.Dept.idxmin()
# Out:
# C:\Users\zbook g6\AppData\Local\Temp\ipykernel_19624\3328458318.py:1: FutureWarning: The behavior of Series.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   df.Dept.idxmin()
# nan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, row1 to row4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       4 non-null      int64
#  1   std_id   4 non-null      int64
#  2   Dept     0 non-null      float64
#  3   new_col  4 non-null      int64
# dtypes: float64(1), int64(3)
# memory usage: 332.0+ bytes

# %%
df['Dept'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df['ID'].sum()
# Out:
# np.int64(10)

# %%
def duplicate(x):
    return x*2


df['std_id'].apply(duplicate)
# Out:
# row1     888
# row2    1110
# row3    1332
# row4    1554
# Name: std_id, dtype: int64

# %%
df['std_id'].apply(lambda x: x*2)
# Out:
# row1     888
# row2    1110
# row3    1332
# row4    1554
# Name: std_id, dtype: int64

# %%
df['ID'].iloc[2]
# Out:
# np.int64(3)

# %%
df.iloc[2,1]
# Out:
# np.int64(666)

# %%
df.Dept.iloc[0:3]
# Out:
# row1   NaN
# row2   NaN
# row3   NaN
# Name: Dept, dtype: float64

# %%
df.Dept.iloc[:]
# Out:
# row1   NaN
# row2   NaN
# row3   NaN
# row4   NaN
# Name: Dept, dtype: float64

# %%
num_col=df.iloc[:,0:2]
cat_col=df.iloc[:,2:3]
print(num_col)
print(cat_col)
# Out:
#       ID  std_id
# row1   1     444
# row2   2     555
# row3   3     666
# row4   4     777
#       Dept
# row1   NaN
# row2   NaN
# row3   NaN
# row4   NaN

# %%
num_col=df.iloc[:,:-1]
target_y=df.iloc[:,-1:]
num_col
# Out:
#       ID  std_id
# row1   1     444
# row2   2     555
# row3   3     666
# row4   4     777

# %%
new_col=df['std_id'] + df.ID
new_col
# Out:
# row1    445
# row2    557
# row3    669
# row4    781
# dtype: int64

# %%
df['new_col']=df['std_id']+ df.ID
df
# Out:
#       ID  std_id  Dept  new_col
# row1   1     444   NaN      445
# row2   2     555   NaN      557
# row3   3     666   NaN      669
# row4   4     777   NaN      781

# %%
df.drop('new_col',axis=1)

#colooooomn
# Out:
#       ID  std_id  Dept
# row1   1     444   NaN
# row2   2     555   NaN
# row3   3     666   NaN
# row4   4     777   NaN

# %%
df.drop('row2',axis=0)

#roooooooooooooooooooooooooow
# Out:
#       ID  std_id  Dept  new_col
# row1   1     444   NaN      445
# row3   3     666   NaN      669
# row4   4     777   NaN      781

# %%
null =df.isnull
null
# Out:
# <bound method DataFrame.isnull of       ID  std_id  Dept  new_col
# row1   1     444   NaN      445
# row2   2     555   NaN      557
# row3   3     666   NaN      669
# row4   4     777   NaN      781>

# %%
df.isnull().sum()
# Out:
# ID         0
# std_id     0
# Dept       4
# new_col    0
# dtype: int64

# %%
null=df.isnull().sum()
pd.DataFrame(null)
# Out:
#          0
# ID       0
# std_id   0
# Dept     4
# new_col  0

# %%
def isNull(df):
    null=df.isnull().sum()
    return (pd.DataFrame(null))

isNull(df)
# Out:
#          0
# ID       0
# std_id   0
# Dept     4
# new_col  0

# %%
from isnullval import isNull
isNull(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 from isnullval import isNull
#       2 isNull(df)
#
# ModuleNotFoundError: No module named 'isnullval'
