# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score ,root_mean_squared_error
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r'C:\Users\zbook g6\Desktop\DEBI-ONL4_AIS2_S2\DEBI-ONL4_AIS2_S2\src\machine_learning\data_analysis\session_14\Salary_Data.csv')

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
plt.Figure(figsize=(3,3))
sns. pairplot (data, x_vars=["YearsExperience"], y_vars=['Salary' ], size=7, kind='scatter')
plt.xlabel("Years")
plt.ylabel("Years")
plt.title("Salary prediction")
plt.show()

# %%
x = data.iloc[:, :-1]  # كل الأعمدة إلا آخر عمود
y = data.iloc[:, -1]

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,train_size=0.8,random_state=9)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (24, 1)
# (24,)

# %%
linear_model = LinearRegression()
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x_train, y_train, color = 'red')
plt.plot(x_train, linear_model.predict(x_train),color = 'blue')
plt.xlabel("salary vs Experience if years")
plt.ylabel("Years of Experience ")
plt.title("Salary prediction")
plt.show()

# %%
plt.scatter(x_test, y_test, color = 'red')
plt.plot(x_test, linear_model.predict(x_test),color = 'blue')
plt.xlabel("salary vs Experience if years")
plt.ylabel("Years of Experience ")
plt.title("Salary prediction")
plt.show()

# %%
y_pred=linear_model.predict(x_test)
y_pred
# Out:
# array([ 60189.69970699,  46053.97672244, 102596.86866063,  55477.79204548,
#         52650.64744857,  44169.21365784])

# %%
msa=mean_squared_error(y_test,y_pred)
print(msa)
# Out:
# 31696369.60136932

# %%
rms=root_mean_squared_error(y_test,y_pred)
rms
# Out:
# 5629.952895128815

# %%
r2score=r2_score(y_test,y_pred)
r2score
# Out:
# 0.9474139668208039

# %%
linear_model.coef_
# Out:
# array([9423.81532303])

# %%
linear_model.intercept_
# Out:
# np.float64(25321.583011776813)

# %%
x = float(input("enter your years of experience"))
y_hat = 9423.81 * x + 25321.58
y_hat
# Out:
# 81864.44

# %%
from gui_linear import SalaryPredictionApp
import tkinter as tk

root = tk.Tk()
app = SalaryPredictionApp(root)
root.mainloop()
